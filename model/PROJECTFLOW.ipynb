# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from scipy.stats import ttest_ind
import random

from sklearn.preprocessing import LabelEncoder # for statistical analysis on gender

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report  # not sure if we keep this in the end

import joblib



# %matplotlib inline

# %%
df = pd.read_csv('brain-proteomics.csv')

# %%
df.head()
# Out:
#            Case  years_to_birth  gender histological_type   race  \
# 0  TCGA-CS-4938              31  female       astrocytoma  white
# 1  TCGA-CS-6665              51  female       astrocytoma  white
# 2  TCGA-CS-6666              22    male       astrocytoma  white
# 3  TCGA-DB-5270              38  female  oligoastrocytoma  white
# 4  TCGA-DB-5273              33    male       astrocytoma  white
#
#                 ethnicity radiation_therapy Grade  Mutation.Count  \
# 0  not hispanic or latino                no    G2              15
# 1  not hispanic or latino               yes    G3              75
# 2  not hispanic or latino               yes    G3              18
# 3  not hispanic or latino                no    G3              16
# 4  not hispanic or latino               yes    G3              16
#
#    Percent.aneuploidy  ...     p27_p  p27_pT157_p  p27_pT198_p  \
# 0            0.069412  ... -0.425127    -0.033398     0.289192
# 1            0.524814  ...  0.076536     0.011809    -0.047973
# 2            0.403165  ...  0.110268     0.066886    -0.066150
# 3            0.061382  ... -0.235321     0.015372    -0.127422
# 4            0.017349  ... -0.343212    -0.250564    -0.234582
#
#    p38_pT180_Y182_p     p53_p  p62-LCK-ligand_p  p70S6K_p  p70S6K_pT389_p  \
# 0          1.060163 -0.407456         -0.470354 -0.107559       -0.060441
# 1         -0.054275 -0.244020          0.106282 -0.034369        0.585072
# 2          0.250434  0.432187         -0.210412  0.290949       -0.893383
# 3         -1.190789  0.105396          0.218569 -0.099136        1.990618
# 4          0.648598 -0.071851         -0.041811 -0.099300       -0.920359
#
#    p90RSK_p  p90RSK_pT359_S363_p
# 0 -0.053104            -0.011132
# 1  0.431720            -0.201412
# 2 -0.693677            -0.055250
# 3  0.166788            -0.235380
# 4 -0.243159            -0.128841
#
# [5 rows x 186 columns]

# %%
gender_age_outcome = df[['years_to_birth', 'gender', 'outcome']]

gender_age_outcome.rename(columns={'years_to_birth': 'age'}, inplace=True)

# %% [markdown]
# ## About the dataset

# %%
fig = px.histogram(gender_age_outcome, x="age",  color="gender", marginal="box",
                   hover_data=gender_age_outcome.columns)
fig.show()
# Out:
# <div>                            <div id="f08113c9-919f-4454-80de-cd72bf936756" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f08113c9-919f-4454-80de-cd72bf936756")) {                    Plotly.newPlot(                        "f08113c9-919f-4454-80de-cd72bf936756",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"gender=female\u003cbr\u003eage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":true,"x":[31,51,38,33,56,36,43,49,40,49,37,43,31,31,35,23,41,58,41,38,41,29,69,62,33,62,26,41,39,23,33,27,44,47,34,52,20,37,18,30,30,25,29,58,51,44,30,37,40,49,33,36,37,34,36,35,59,52,32,73,23,38,48,22,57,33,48,30,36,44,54,34,61,57,60,51,59,60,74,45,63,60,46,59,49,53,61,71,53,57,37,67,38,65,55,56,34,62,66,32,57,53,53,48,55,37,74,42,48,47,31,42,50,74,61,29,29,41,20,64,30,38,51,45,41,64,43,28,52,58,56,53,73,38,45,35],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","customdata":[["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",0],["female",1],["female",1],["female",1],["female",1],["female",1],["female",0],["female",0],["female",0],["female",0],["female",1],["female",0],["female",1],["female",0],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",0],["female",0],["female",1],["female",1],["female",1],["female",1],["female",0],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",0],["female",0],["female",1],["female",1],["female",1],["female",1],["female",0],["female",1],["female",1],["female",1],["female",1],["female",1],["female",0],["female",1],["female",1],["female",1],["female",0],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",0],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",1],["female",0],["female",1],["female",1],["female",1],["female",1],["female",1],["female",0],["female",0],["female",0],["female",1],["female",0],["female",1],["female",1],["female",1],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",1],["female",0],["female",1],["female",1],["female",1],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",0],["female",1],["female",0],["female",1],["female",0],["female",0],["female",1],["female",1],["female",1],["female",0]],"hovertemplate":"gender=%{customdata[0]}\u003cbr\u003eage=%{x}\u003cbr\u003eoutcome=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","marker":{"color":"#636efa"},"name":"female","notched":true,"offsetgroup":"female","showlegend":false,"x":[31,51,38,33,56,36,43,49,40,49,37,43,31,31,35,23,41,58,41,38,41,29,69,62,33,62,26,41,39,23,33,27,44,47,34,52,20,37,18,30,30,25,29,58,51,44,30,37,40,49,33,36,37,34,36,35,59,52,32,73,23,38,48,22,57,33,48,30,36,44,54,34,61,57,60,51,59,60,74,45,63,60,46,59,49,53,61,71,53,57,37,67,38,65,55,56,34,62,66,32,57,53,53,48,55,37,74,42,48,47,31,42,50,74,61,29,29,41,20,64,30,38,51,45,41,64,43,28,52,58,56,53,73,38,45,35],"xaxis":"x2","yaxis":"y2","type":"box"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"gender=male\u003cbr\u003eage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"mal ...

# %%
outcome_mapping = {0: 'Oligodendroglioma', 1: 'Astrocytoma'}

# %%
# Replace numeric values in the 'outcome' column with their corresponding labels
gender_age_outcome['outcome'] = gender_age_outcome['outcome'].map(outcome_mapping)

# %%
# Calculate the percentages using value_counts(normalize=True)
outcome_percentages = gender_age_outcome['outcome'].value_counts(normalize=True) * 100

# %%
# Plot the pie chart with real names as labels
fig = px.pie(names=outcome_percentages.index, values=outcome_percentages.values,
             title='Distribution of the two different outcomes', labels=outcome_percentages.index)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="d665a981-adbd-47c0-9831-f3a63ba14569" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d665a981-adbd-47c0-9831-f3a63ba14569")) {                    Plotly.newPlot(                        "d665a981-adbd-47c0-9831-f3a63ba14569",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Astrocytoma","Oligodendroglioma"],"legendgroup":"","name":"","showlegend":true,"values":[60.130718954248366,39.869281045751634],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[ ...
#
# var gd = document.getElementBy

# %% [markdown]
# ## Statistical Analysis

# %% [markdown]
# ### Statistical analysis of the 176 proteins

# %%
proteins_outcome = df.drop(['Case', 'years_to_birth', 'gender', 'histological_type', 'race',
       'ethnicity', 'radiation_therapy', 'Grade', 'Mutation.Count',
       'Percent.aneuploidy', 'IDH.status'], axis=1)

# %%
from scipy.stats import ttest_ind

# Initialize an empty list to store protein names and corresponding p-values
protein_p_values = []

# Loop through each protein column and perform t-test
for column in proteins_outcome.drop('outcome', axis=1):  # Exclude the 'outcome' column
    group_0 = proteins_outcome[proteins_outcome['outcome'] == 0][column]
    group_1 = proteins_outcome[proteins_outcome['outcome'] == 1][column]
    t_stat, p_val = ttest_ind(group_0, group_1)
    protein_p_values.append({'Protein': column, 'p-value': p_val})

# Create a DataFrame from the list of dictionaries
p_values_df = pd.DataFrame(protein_p_values)

# Sort the DataFrame by p-values
p_values_df = p_values_df.sort_values(by='p-value')

# Reset index
p_values_df.reset_index(drop=True, inplace=True)

# Print the DataFrame
p_values_df
# Out:
#            Protein       p-value
# 0            Syk_p  3.385636e-11
# 1      YAP_pS127_p  1.678460e-09
# 2             AR_p  3.858150e-09
# 3           ACC1_p  7.671502e-07
# 4            YAP_p  1.139554e-06
# ..             ...           ...
# 169  PEA15_pS116_p  9.517016e-01
# 170         ASNS_p  9.659298e-01
# 171  Fibronectin_p  9.669654e-01
# 172    Cyclin_E2_p  9.938696e-01
# 173        Rad50_p  9.989151e-01
#
# [174 rows x 2 columns]

# %%
# Bonferoni correction for p-values


# Number of comparisons (number of protein columns)
num_comparisons = len(proteins_outcome.drop('outcome', axis=1))

# Perform Bonferroni correction
p_values_df['Adjusted p-value'] = p_values_df['p-value'] * num_comparisons

# Ensure adjusted p-values do not exceed 1
p_values_df['Adjusted p-value'] = p_values_df['Adjusted p-value'].clip(upper=1)

# Print the DataFrame with adjusted p-values
p_values_df
# Out:
#            Protein       p-value  Adjusted p-value
# 0            Syk_p  3.385636e-11      1.036005e-08
# 1      YAP_pS127_p  1.678460e-09      5.136089e-07
# 2             AR_p  3.858150e-09      1.180594e-06
# 3           ACC1_p  7.671502e-07      2.347480e-04
# 4            YAP_p  1.139554e-06      3.487034e-04
# ..             ...           ...               ...
# 169  PEA15_pS116_p  9.517016e-01      1.000000e+00
# 170         ASNS_p  9.659298e-01      1.000000e+00
# 171  Fibronectin_p  9.669654e-01      1.000000e+00
# 172    Cyclin_E2_p  9.938696e-01      1.000000e+00
# 173        Rad50_p  9.989151e-01      1.000000e+00
#
# [174 rows x 3 columns]

# %%
p_values_df[p_values_df['Adjusted p-value']<= 0.05]
# Out:
#             Protein       p-value  Adjusted p-value
# 0             Syk_p  3.385636e-11      1.036005e-08
# 1       YAP_pS127_p  1.678460e-09      5.136089e-07
# 2              AR_p  3.858150e-09      1.180594e-06
# 3            ACC1_p  7.671502e-07      2.347480e-04
# 4             YAP_p  1.139554e-06      3.487034e-04
# 5     HER3_pY1289_p  1.153899e-06      3.530932e-04
# 6           c-Kit_p  2.440837e-06      7.468962e-04
# 7        ACC_pS79_p  4.694171e-06      1.436416e-03
# 8     STAT3_pY705_p  8.408725e-06      2.573070e-03
# 9            DJ-1_p  1.042737e-05      3.190774e-03
# 10          53BP1_p  2.264124e-05      6.928220e-03
# 11            p27_p  4.736816e-05      1.449466e-02
# 12           PDK1_p  5.587816e-05      1.709872e-02
# 13  S6_pS235_S236_p  7.714018e-05      2.360490e-02
# 14          PRDX1_p  9.839342e-05      3.010839e-02
# 15            Bax_p  1.055987e-04      3.231319e-02
# 16           IRS1_p  1.448588e-04      4.432681e-02

# %%
P17_list = p_values_df[p_values_df['Adjusted p-value']<= 0.05]['Protein'].tolist()
P17_list
# Out:
# ['Syk_p',
#  'YAP_pS127_p',
#  'AR_p',
#  'ACC1_p',
#  'YAP_p',
#  'HER3_pY1289_p',
#  'c-Kit_p',
#  'ACC_pS79_p',
#  'STAT3_pY705_p',
#  'DJ-1_p',
#  '53BP1_p',
#  'p27_p',
#  'PDK1_p',
#  'S6_pS235_S236_p',
#  'PRDX1_p',
#  'Bax_p',
#  'IRS1_p']

# %% [markdown]
# ### Visaulization of the 17 significant proteins

# %%
# Define the mapping from numeric values to labels
outcome_mapping = {0: 'Oligodendroglioma', 1: 'Astrocytoma'}

# %%
# Melt the dataframe to convert specific columns into a single column
melted_df_sign = df.melt(id_vars='outcome', value_vars=P17_list, var_name='Proteins', value_name='Protein levels')

# Replace numeric values in the 'outcome' column with their corresponding labels
melted_df_sign['outcome'] = melted_df_sign['outcome'].map(outcome_mapping)

# Plot the boxplot using Plotly
fig = px.box(melted_df_sign, x='Proteins', y='Protein levels', color='outcome',
             title='Boxplots of the differentially expressed proteins',
             category_orders={'outcome': ['Oligodendroglioma', 'Astrocytoma']})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="316aaf19-643c-40b1-8d54-59ec3e7ab705" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("316aaf19-643c-40b1-8d54-59ec3e7ab705")) {                    Plotly.newPlot(                        "316aaf19-643c-40b1-8d54-59ec3e7ab705",                        [{"alignmentgroup":"True","hovertemplate":"outcome=Oligodendroglioma\u003cbr\u003eProteins=%{x}\u003cbr\u003eProtein levels=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oligodendroglioma","marker":{"color":"#636efa"},"name":"Oligodendroglioma","notched":false,"offsetgroup":"Oligodendroglioma","orientation":"v","showlegend":true,"x":["Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","Syk_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","YAP_pS127_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p","AR_p"," ...

# %%
import random


# Select 5 random proteins from the P17_list
random_proteins = random.sample(P17_list, 5)

# Melt the dataframe to convert the selected columns into a single column
melted_df_random = df.melt(id_vars='outcome', value_vars=random_proteins, var_name='Proteins', value_name='Protein Levels')

# Replace numeric values in the 'outcome' column with their corresponding labels
melted_df_random['outcome'] = melted_df_random['outcome'].map(outcome_mapping)

# Plot the boxplot using Plotly
fig = px.box(melted_df_random, x='Proteins', y='Protein Levels', color='outcome',
             title='Boxplot of 5 Randomly Selected Proteins',
             category_orders={'outcome': ['Oligodendroglioma', 'Astrocytoma']})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="3c233f33-43d0-41a2-94e7-e2025d5d324b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c233f33-43d0-41a2-94e7-e2025d5d324b")) {                    Plotly.newPlot(                        "3c233f33-43d0-41a2-94e7-e2025d5d324b",                        [{"alignmentgroup":"True","hovertemplate":"outcome=Oligodendroglioma\u003cbr\u003eProteins=%{x}\u003cbr\u003eProtein Levels=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oligodendroglioma","marker":{"color":"#636efa"},"name":"Oligodendroglioma","notched":false,"offsetgroup":"Oligodendroglioma","orientation":"v","showlegend":true,"x":["S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","S6_pS235_S236_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p27_p","p2 ...

# %% [markdown]
# ### Statistical analysis of the age and gender

# %%
gender_age_outcome = df[['years_to_birth', 'gender', 'outcome']]

# %%
from sklearn.preprocessing import LabelEncoder

# Create a label encoder object
label_encoder = LabelEncoder()

# Encode the 'gender' column
gender_age_outcome['gender_encoded'] = label_encoder.fit_transform(gender_age_outcome['gender'])

# %%
gender_age_outcome.head()
# Out:
#    years_to_birth  gender  outcome  gender_encoded
# 0              31  female        1               0
# 1              51  female        1               0
# 2              22    male        1               1
# 3              38  female        1               0
# 4              33    male        1               1

# %%
# Perform independent t-tests for 'age' and 'gender' columns based on the 'outcome' column
t_stat_age, p_val_age = ttest_ind(gender_age_outcome[gender_age_outcome['outcome'] == 0]['years_to_birth'], 
                                  gender_age_outcome[gender_age_outcome['outcome'] == 1]['years_to_birth'])
t_stat_gender, p_val_gender = ttest_ind(gender_age_outcome[gender_age_outcome['outcome'] == 0]['gender_encoded'], 
                                        gender_age_outcome[gender_age_outcome['outcome'] == 1]['gender_encoded'])

# Print the p-values for 'age' and 'gender' columns
print(f"p-value for age: {p_val_age}")
print(f"p-value for gender: {p_val_gender}")
# Out:
# p-value for age: 0.01106098915501576
# p-value for gender: 0.7748621104407485

# %%
X = df.drop(['Case', 'gender', 'histological_type', 'race', 'ethnicity', 'radiation_therapy', 'Grade', 'Mutation.Count', 'Percent.aneuploidy', 'IDH.status', 'outcome'], axis = 1)

y = df['outcome']

# %%
P17_list = ['Syk_p',
 'YAP_pS127_p',
 'AR_p',
 'ACC1_p',
 'YAP_p',
 'HER3_pY1289_p',
 'c-Kit_p',
 'ACC_pS79_p',
 'STAT3_pY705_p',
 'DJ-1_p',
 '53BP1_p',
 'p27_p',
 'PDK1_p',
 'S6_pS235_S236_p',
 'PRDX1_p',
 'Bax_p',
 'IRS1_p']

# %%
X_P17 = X[['years_to_birth'] + P17_list]

# %%
from sklearn.model_selection import train_test_split

# train test split 

X_train, X_val_test, y_train, y_val_test = train_test_split(X_P17, y, test_size=0.35, stratify=y)


X_val, X_test, y_val, y_test = train_test_split(X_val_test, y_val_test, test_size=0.5, stratify=y_val_test)

# %%
from imblearn.over_sampling import SMOTE

# doubling the datapoints for each class of the training set

sampler = SMOTE(sampling_strategy={0: y_train.value_counts()[0]*2, 1: y_train.value_counts()[1]*2})

# %%
# reassigning X_train - y_train after SMOTE

X_train, y_train = sampler.fit_resample(X_train, y_train)

# %%
from sklearn.preprocessing import MinMaxScaler


preprocessor = MinMaxScaler()


preprocessor
# Out:
# MinMaxScaler()

# %%
# fit and transform X_train on the preprocessor

X_train = preprocessor.fit_transform(X_train)

# %%
# Transform X_val and X_test

X_val = preprocessor.transform(X_val)

X_test = preprocessor.transform(X_test)

# %%
features_P17_age = X_P17.columns

# %% [markdown]
# ## the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg_model_X = LogisticRegression(max_iter=1000)

log_reg_model_X.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred_log_X = log_reg_model_X.predict(X_val)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Evaluate the model
accuracy = accuracy_score(y_val, y_pred_log_X)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_val, y_pred_log_X))
# Out:
# Accuracy: 0.7592592592592593
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.52      0.63        21
#            1       0.75      0.91      0.82        33
#
#     accuracy                           0.76        54
#    macro avg       0.77      0.72      0.73        54
# weighted avg       0.76      0.76      0.75        54

# %%
import joblib


# Save the models

joblib.dump(log_reg_model_X, 'log_reg_model.pkl')
# Out:
# ['log_reg_model.pkl']

# %%
# load the saved model 

loaded_log_reg_model = joblib.load('log_reg_model.pkl')

# Make predictions using the loaded model

log_reg_predictions = loaded_log_reg_model.predict(X_val)

# Evaluate the accuracy of the predictions
log_reg_accuracy = accuracy_score(y_val, log_reg_predictions)

print("Log Reg Model Accuracy:", log_reg_accuracy)
# Out:
# Log Reg Model Accuracy: 0.7592592592592593
